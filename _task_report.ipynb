# %%
FOLDER = 'resources/'

import numpy as np
import pandas as pd
import time, datetime
from ast import literal_eval
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile

#%matplotlib inline
plt.style.use('fivethirtyeight')
plt.rc('font', family='Times New Roman')

pd.set_option('max_rows', 50)

time_format = '%b %d, %H:%M'

start_time = time.time()
current_time = pd.read_csv(FOLDER + 'current_time.csv').current_time[0]
twr          = pd.read_csv(FOLDER + 'team_work_region.csv', converters={'twr':str})
links        = pd.read_csv(FOLDER + 'link.csv')
stations     = pd.read_csv(FOLDER + 'station.csv', converters={'station':str})
train_info   = pd.read_csv(FOLDER + 'train_info.csv', converters={'train': str, 'st_from':str, 'st_to':str, 'oper_location':str,
                                                                 'st_from':str, 'st_to':str})
train_plan   = pd.read_csv(FOLDER + 'slot_train.csv', converters={'train': str, 'st_from':str, 'st_to':str})
loco_info    = pd.read_csv(FOLDER + 'loco_attributes.csv', converters={'train':str, 'loco':str, 'depot':str,
                                                                      'st_from':str, 'st_to':str})
loco_plan    = pd.read_csv(FOLDER + 'slot_loco.csv', converters={'train':str, 'loco':str, 'st_from':str, 'st_to':str})
team_info    = pd.read_csv(FOLDER + 'team_attributes.csv', converters={'team':str,'depot':str, 'oper_location':str, \
                                                                 'st_from':str, 'st_to':str, 'loco':str, 'depot_st':str})
team_plan    = pd.read_csv(FOLDER + 'slot_team.csv', converters={'team':str,'loco':str, 'st_from':str, 'st_to':str})
loco_series  = pd.read_csv(FOLDER + 'loco_series.csv')

team_info.regions = team_info.regions.apply(literal_eval)
st_names = stations[['station', 'name', 'esr']].drop_duplicates().set_index('station')
print('Время составления отчета:', time.strftime(time_format, time.localtime()))
print('Время запуска планировщика: %s (%d)' % (time.strftime(time_format, time.localtime(current_time)), current_time))
# Out:
# Planning start time: Jul 05, 13:31 (1467714691)

# %%
# Мержим таблицы _plan и _info для поездов, локомотивов и бригад
# Добавляем во все таблицы названия станций на маршруте и времена отправления/прибытия в читабельном формате

def add_info(df):    
    if 'st_from' in df.columns:
        df['st_from_name'] = df.st_from.map(st_names.name)
    if 'st_to' in df.columns:
        df['st_to_name'] = df.st_to.map(st_names.name)
    if 'time_start' in df.columns:
        df['time_start_norm'] = df.time_start.apply(lambda x: time.strftime(time_format, time.localtime(x)))
    if 'time_end' in df.columns:
        df['time_end_norm'] = df.time_end.apply(lambda x: time.strftime(time_format, time.localtime(x)))
    if 'oper_location' in df.columns:
        df['oper_location_name'] = df.oper_location.map(st_names.name)    
        df.oper_location_name.fillna(0, inplace=True)
    if ('oper_location' in df.columns) & ('st_from' in df.columns) & ('st_to' in df.columns):        
        df['loc_name'] = df.oper_location_name
        df.loc[df.loc_name == 0, 'loc_name'] = df.st_from_name + ' - ' + df.st_to_name
    
add_info(train_plan)
add_info(loco_plan)
add_info(team_plan)
add_info(loco_info)
add_info(team_info)
add_info(train_info)
train_plan = train_plan.merge(train_info, on='train', suffixes=('', '_info'), how='left')
loco_plan = loco_plan.merge(loco_info, on='loco', suffixes=('', '_info'), how='left')
team_plan = team_plan.merge(team_info, on='team', suffixes=('', '_info'), how='left')
team_plan['team_type'] = team_plan.team.apply(lambda x: 'Реальная' if str(x)[0] == '2' else 'Фейковая')

# %%
def nice_time(t):
    return time.strftime(time_format, time.localtime(t)) if t > 0 else ''

# %%
REPORT_FOLDER = 'report/'
PRINT = True
report = ''

def add_line(line, p=PRINT):    
    global report        
    if p:                
        if type(line) == pd.core.frame.DataFrame:
            print(line.to_string(index=False))
        elif type(line) == pd.core.series.Series:
            print(line.to_string())
        else:
            print(line)
    if type(line) == pd.core.frame.DataFrame:        
        report += ('%s<br>' % line.to_html(index=False))
    elif type(line) == pd.core.series.Series:
        report += ('%s<br>' % line.to_frame().reset_index().to_html(index=False))
    else:
        report += ('%s<br>' % line)
    
def add_header(header, h=4, p=PRINT):
    global report
    report += ('<h%d>%s</h%d>' % (h, header, h))
    if p:
        print(header)

def add_image(filename):
    global report
    report += ('<img src="%s" alt="%s" height="40%%">' % (filename, filename))

def create_report(filename):
    global report
    report = report.replace('<table border="1" class="dataframe">','<table class="table table-striped">')
    html_string = '''
        <html>
            <head>
                <link rel="stylesheet" href="skeleton.css">
                <style>body{ margin:20 20; background:whitesmoke; }
                table {table-layout : fixed}
                </style>
            </head>
            <body>                
                # %s
            </body>
        </html>''' % (report)
    f = open(filename,'w', encoding='utf-8-sig')
    f.write(html_string)
    f.close()
    print('Report created: %s' % filename)
    
def create_zip(filename):
    zip_filename = filename[:-5] + '.zip'
    zf = zipfile.ZipFile(zip_filename, mode='w')
    try:
        #print 'Отчет заархивирован в файл'
        zf.write(filename)
        zf.write('report\skeleton.css')
    finally:
        print('Zip-file created: %s' % zip_filename)
        zf.close()

# %%
import sys
if len(sys.argv) > 1:
    if sys.argv[1].upper() in stations.name.values:
        st_name = sys.argv[1]
    else: st_name = 'ИРКУТСК-СОРТИРОВОЧНЫЙ'
else: st_name = 'ИРКУТСК-СОРТИРОВОЧНЫЙ'
add_line('Отчет строится для поездов формированием на станции %s' % st_name)
add_line('Время начала планирования: %s' % nice_time(current_time))
# Out:
# Отчет строится для поездов формированием на станции ИРКУТСК-СОРТИРОВОЧНЫЙ
# Время начала планирования: Jul 05, 13:31

# %%
train_plan['train_type'] = train_plan.train.apply(lambda x: int(x[0]))
train_plan.loc[train_plan.train_type == 9, 'task'] = train_plan.loc[train_plan.train_type == 9, 'train'].apply(lambda x: x[4:9])
sf = train_plan[train_plan.train_type == 9]
sf_start = sf.drop_duplicates('train')
sf_irk = sf_start[sf_start.st_from_name == st_name]
add_header('Все запланированные поезда своего формирования по направлениям:')
add_line(sf_irk.st_to_name.value_counts())
# Out:
# Все запланированные поезда своего формирования по направлениям:
# ГОНЧАРОВО     43
# БАТАРЕЙНАЯ    26

# %%
def get_planned_trains(row):
    return sf_irk[(sf_irk.st_to_name == row.st_next_name) & (sf_irk.time_start >= row.time_start)
                 & (sf_irk.time_start < row.time_end)].train.count()

#f = {'number':'sum', 'id':'unique'}
task = pd.read_csv(FOLDER + 'task.csv', dtype={'st_from':str, 'st_to':str, 'st_next':str})
add_info(task)
task['duration'] = task.time_end - task.time_start
task['st_next_name'] = task.st_next.map(st_names.name)
cols = ['id', 'time_start', 'time_end', 'time_start_norm', 'time_end_norm', 'duration', 'st_from_name', 'st_next_name', 'number']
a = task[task.st_from_name == st_name].sort_values(['time_start', 'st_to_name'])[cols].drop_duplicates()
b = a.groupby(['time_start', 'time_end', 'time_start_norm', 'time_end_norm', 'st_next_name'])\
        .agg({'number':'sum', 'id':'unique'}).reset_index()
b['plan_at_time'] = b.apply(lambda row: get_planned_trains(row), axis=1)
b = b[['id', 'time_start', 'time_end', 'time_start_norm', 'time_end_norm', 'st_next_name', 'number', 'plan_at_time']]
add_header('Задания (сгруппированные по направлениям) и кол-во поездов, запланированных в нужное время:')
add_line(b)
# Out:
# Задания (сгруппированные по направлениям) и кол-во поездов, запланированных в нужное время:
#                            id  time_start    time_end time_start_norm  time_end_norm st_next_name  number  plan_at_time
#                [200290012394]  1467687600  1467730800   Jul 05, 06:00  Jul 05, 18:00   БАТАРЕЙНАЯ       0             0
#  [200290012393, 200220028815]  1467687600  1467730800   Jul 05, 06:00  Jul 05, 18:00    ГОНЧАРОВО       6             0
#                [200290012394]  1467730800  1467774000   Jul 05, 18:00  Jul 06, 06:00   БАТАРЕЙНАЯ      13             5
#  [200290012393, 200220028815]  1467730800  1467774000   Jul 05, 18:00  Jul 06, 06:00    ГОНЧАРОВО      18             5
#                [200290012394]  1467774000  1467817200   Jul 06, 06:00  Jul 06, 18:00   БАТАРЕЙНАЯ      13             6
#  [200290012393, 200220028815]  1467774000  1467817200   Jul 06, 06:00  Jul 06, 18:00    ГОНЧАРОВО      19             6

# %%
b['part_id'] = b['id'].apply(lambda x: [str(t)[7:] for t in x])
problem_tasks = b[b.number > b.plan_at_time].iloc[0]['id']
problem_tasks_part_id = b[b.number > b.plan_at_time].iloc[0]['part_id']
add_header('Примеры заданий, по которым запланировано недостаточно поездов: %s' % problem_tasks)
# Out:
# Примеры заданий, по которым запланировано недостаточно поездов: [200290012393 200220028815]

# %%
cols = ['train', 'task', 'st_from_name', 'st_to_name', 'time_start_norm']
add_header('Поезда по этим заданиям (отсортированы по id):')
add_line(sf_irk[sf_irk.task.isin(problem_tasks_part_id)].sort_values('train')[cols])
# Out:
# Поезда по этим заданиям (отсортированы по id):
#            train   task           st_from_name st_to_name time_start_norm
#  999912393012000  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 22:20
#  999912393012002  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 05, 20:05
#  999912393012004  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 15:25
#  999912393012006  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 23:38
#  999912393022000  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 02:54
#  999912393022002  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 10:20
#  999912393022004  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 12:25
#  999912393022006  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 12:10
#  999912393022008  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 08:41
#  999912393022010  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 22:24
#  999912393022012  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 14:25
#  999912393022014  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 08, 10:44
#  999912393022016  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 09, 13:28
#  999912393022018  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 08, 09:06
#  999912393022020  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 21:25
#  999912393022022  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 18:15
#  999912393022024  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 22:42
#  999912393022026  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 22:30
#  999912393022028  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 22:20
#  999912393022030  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 08, 03:40
#  999912393022032  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 23:47
#  999912393032000  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 23:00
#  999912393032002  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 01:35
#  999912393032004  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 00:55
#  999912393032006  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 09:02
#  999912393032008  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 15:35
#  999912393032010  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 22:13
#  999912393032012  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 08:15
#  999912393032014  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 12:57
#  999912393032016  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 09:21
#  999912393032018  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 06:29
#  999912393032020  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 02:50
#  999912393032022  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 11:55
#  999912393032024  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 21:15
#  999912393032026  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 22:50
#  999912393032028  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 01:34
#  999912393032030  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 08, 07:58
#  999912393032032  12393  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 09:26
#  999928815012000  28815  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 05, 22:20
#  999928815012002  28815  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 06, 18:05
#  999928815022000  28815  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 09:59
#  999928815032000  28815  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 08, 08:06
#  999928815032002  28815  ИРКУТСК-СОРТИРОВОЧНЫЙ  ГОНЧАРОВО   Jul 07, 01:00

# %%
filename = REPORT_FOLDER + 'task_' + time.strftime('%Y%m%d_%H%M%S', time.localtime(time.time())) + '.html'
create_report(filename)
create_zip(filename)
# Out:
# Report created: report/task_20160705_191510.html
# Zip-file created: report/task_20160705_191510.zip

# %%
st_name = 'ИРКУТСК-СОРТИРОВОЧНЫЙ'
loco_info['ser_name'] = loco_info.series.map(loco_series.set_index('ser_id').ser_name)
loco_info['oper_time_f'] = loco_info.oper_time.map(nice_time)
irk_loco = loco_info[(loco_info.loc_name == st_name) & (loco_info.ltype == 1)][['loco', 'ser_name', 'sections', 'regions', 'oper', 'oper_time_f', 'loc_name', 'tts', 'dts']]
irk_loco.loco.count()
# Out:
# 16

# %%
cols = ['loco', 'st_from_name', 'st_to_name', 'time_start_norm', 'time_end_norm', 'train', 'end']
loco_plan['end'] = ((loco_plan.loco != loco_plan.loco.shift(-1)) | (loco_plan.train != loco_plan.train.shift(-1))) & (loco_plan.train != '-1')
loco_ends = loco_plan[loco_plan.end == True]
loco_ends[loco_ends.st_to_name == st_name].sort_values('time_end')[cols]
# Out:
#                loco st_from_name             st_to_name time_start_norm  \
# 44112  200200058242   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 13:36
# 17216  200200090764   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 13:54
# 27004  200200069085    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 13:58
# 12549  200200060042    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 13:59
# 14877  200200079007   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 14:25
# 38534  200200106746    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 14:15
# 10455  200200097482   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 14:59
# 43844  200200092705    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 15:04
# 28201  200200091899    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 15:09
# 34900  200200099378    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 15:25
# 23459  200200096438    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 15:35
# 32708  200200107249   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 16:57
# 21600  200200069644    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 17:06
# 33505  200200048802    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 17:12
# 45859  200200098444    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 17:25
# 7504   200200081900    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 17:52
# 13758  200219082444    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 18:02
# 42990  200200102557   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 19:05
# 29576  200200094906   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 19:25
# 23718  200200078846    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 19:14
# 18387  200200096562   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 19:40
# 8751   200200077630   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 20:29
# 47686  200200032290    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 20:19
# 33767  200200083761    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 20:39
# 12405  200200086564    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 05, 21:14
# ...             ...          ...                    ...             ...
# 51510  200200089421   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 12:48
# 29629  200200094906    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 13:13
# 39033  200200088772    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 14:06
# 15882  200200104538   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 14:40
# 42587  200200093890    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 16:02
# 48176  200200089210    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 16:25
# 19029  200202312703   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 17:07
# 32326  200200088279    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 17:22
# 43313  200200089075   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 18:42
# 15288  200200083032   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 19:05
# 50842  200200080762    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 18:47
# 13076  200200090952    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 19:03
# 1899   200200082426    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 19:28
# 10618  200200066124    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 21:33
# 14208  200200096169    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 08, 23:45
# 34722  210213382232    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 09, 01:14
# 44206  200200088884    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 09, 05:21
# 26550  200200095163    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 09, 07:24
# 7427   200200086207    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 09, 10:51
# 41731  200200092832    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 09, 20:57
# 9144   200200105038    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 09, 21:53
# 28818  200200099266    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 09, 22:53
# 42107  200200098197    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 10, 09:21
# 17869  200200038532    ГОНЧАРОВО  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 10, 10:46
# 21216  200200082859   БАТАРЕЙНАЯ  ИРКУТСК-СОРТИРОВОЧНЫЙ   Jul 10, 14:03
#
#        time_end_norm            train   end
# 44112  Jul 05, 13:39     200230507247  True
# 17216  Jul 05, 13:56     220205083775  True
# 27004  Jul 05, 14:22   88880001214597  True
# 12549  Jul 05, 14:23     220206983279  True
# 14877  Jul 05, 14:28     210217145693  True
# 38534  Jul 05, 14:39     200230254023  True
# 10455  Jul 05, 15:01     210216905309  True
# 43844  Jul 05, 15:39     220206154686  True
# 28201  Jul 05, 15:44     220206945716  True
# 34900  Jul 05, 16:00     220206873296  True
# 23459  Jul 05, 16:10     220206360658  True
# 32708  Jul 05, 16:59     210216922616  True
# 21600  Jul 05, 17:41   88880001214601  True
# 33505  Jul 05, 17:47     200230320209  True
# 45859  Jul 05, 18:00   88880013394835  True
# 7504   Jul 05, 18:18     200230292389  True
# 13758  Jul 05, 18:26     220207437384  True
# 42990  Jul 05, 19:07     200230790827  True
# 29576  Jul 05, 19:27     210216849394  True
# 23718  Jul 05, 19:38     210217314294  True
# 18387  Jul 05, 19:42     210216922674  True
# 8751   Jul 05, 20:31     210217106391  True
# 47686  Jul 05, 20:43     200230467755  True
# 33767  Jul 05, 21:03     220207149901  True
# 12405  Jul 05, 21:38     210217336013  True
# ...              ...              ...   ...
# 51510  Jul 08, 12:51     200230889810  True
# 29629  Jul 08, 13:37     200230584992  True
# 39033  Jul 08, 14:30     210217197130  True
# 15882  Jul 08, 14:43  999928811012000  True
# 42587  Jul 08, 16:37     220207734815  True
# 48176  Jul 08, 17:00     200230875087  True
# 19029  Jul 08, 17:09  999912385022008  True
# 32326  Jul 08, 17:57     200230833246  True
# 43313  Jul 08, 18:44  999912385032016  True
# 15288  Jul 08, 19:07  999912389022000  True
# 50842  Jul 08, 19:11     200230372642  True
# 13076  Jul 08, 19:27     200230809375  True
# 1899   Jul 08, 19:52     200230479424  True
# 10618  Jul 08, 21:57     200230855553  True
# 14208  Jul 09, 00:09     200230223549  True
# 34722  Jul 09, 01:38     210217221936  True
# 44206  Jul 09, 05:46     200230765414  True
# 26550  Jul 09, 07:48     210217319365  True
# 7427   Jul 09, 11:15   88880015604727  True
# 41731  Jul 09, 21:21     210217266438  True
# 9144   Jul 09, 22:17     200230356216  True
# 28818  Jul 09, 23:17     210217134606  True
# 42107  Jul 10, 09:45     200230809379  True
# 17869  Jul 10, 11:10     220207413368  True
# 21216  Jul 10, 14:05  999928813032000  True
#
# [196 rows x 7 columns]
